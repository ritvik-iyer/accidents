# %%
import pandas as pd
import numpy as np

# %%
train1 = pd.read_csv('stat154_cleaned_ryan.csv')
train2 = pd.read_csv('train.csv')

# %%
train1.head()
# Out:
#    Unnamed: 0  X weather.ymd weather.md  weather.mon  temp.imp.zip  \
# 0           1  1  2018-07-20      07-20            7          75.0
# 1           2  2  2020-12-27      12-27           12          36.0
# 2           3  3  2020-12-20      12-20           12          57.0
# 3           4  4  2016-09-28      09-28            9          73.4
# 4           5  5  2020-02-12      02-12            2          47.0
#
#    humid.imp.zip  pressure.imp.zip  visibility.imp.zip wind.d.imp.zip  ...  \
# 0             66             29.90                10.0              S  ...
# 1             53             29.97                10.0              W  ...
# 2            100             30.06                 4.0            ENE  ...
# 3             53             29.89                10.0              S  ...
# 4             61             29.40                10.0            WSW  ...
#
#                                          Description             Street  Side  \
# ...

# %%
train1.columns
# Out:
# Index(['Unnamed: 0', 'X', 'weather.ymd', 'weather.md', 'weather.mon',
#        'temp.imp.zip', 'humid.imp.zip', 'pressure.imp.zip',
#        'visibility.imp.zip', 'wind.d.imp.zip', 'wind.speed.imp.zip', 'light',
#        'heavy', 'rain', 'snow', 'storm', 'windy', 'haze', 'Start_Time',
#        'End_Time', 'Duration', 'Start_Lat', 'Start_Lng', 'Distance.mi',
#        'Description', 'Street', 'Side', 'City', 'County', 'State', 'Zipcode',
#        'Country', 'Timezone', 'Airport_Code'],
#       dtype='object')

# %%
len(train1), len(train2)
# Out:
# (2962779, 2962779)

# %%
pd.to_datetime(train['Start_Time'])[4].month
# Out:
# 2

# %%
pd.Series.mode(train['Sunrise_Sunset']).iloc[0]
# Out:
# 'Day'

# %%
def replace_na_sunrise_sunset(series):
    

def fill_na_sunrise_sunset(row_idx, tbl=train):
    ref_row = train.loc[:, row_idx]
    state = tbl.loc[row_idx, 'State']
    month = tbl.loc[row_idx, 'Start_Time'].month
    hr = tbl.loc[row_idx, 'Start_Time'].hour
    filtered_rows = tbl[(tbl['State'] == state) & 
                       (tbl['Start_Time'].dt.month == month) &
                       (tbl['Start_Time'].dt.hour == hr)]
    replace = pd.Series.mode(filtered_rows['Sunrise_Sunset']).iloc[0]
    return replace

fill_na_map = np.vectorize(fill_na_sunrise_sunset)

# %%
train_subset = train.loc[:, 'Amenity':'Astronomical_Twilight']
len(train_subset.loc[:, 'Amenity':'Turning_Loop'].dropna())/len(train_subset)
# Out:
# 1.0

# %%
train_subset.dropna().shape[0]/train_subset.shape[0]
# Out:
# 0.9999648978205934

# %%
na_rows = train_subset[~train_subset.notnull().all(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-bb92ae52312a> in <module>
# ----> 1 na_rows = train_subset[~train_subset.notnull().all(axis=1)]
#
# NameError: name 'train_subset' is not defined

# %%
# impute based on same state, month, hour

# %%
na_rows
# Out:
#          Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 987        False  False     False     False     False    False    False
# 59043      False  False     False     False     False    False    False
# 110832     False  False     False     False     False    False    False
# 215846     False  False     False     False      True    False    False
# 281581     False  False     False     False     False    False    False
# ...          ...    ...       ...       ...       ...      ...      ...
# 2821200    False  False     False     False     False    False    False
# 2860516    False  False     False     False      True    False    False
# 2916589    False  False     False     False      True    False    False
# 2928535    False  False      True     False     False    False    False
# 2931958    False  False     False     False      True    False    False
#
#          Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# ...

# %%
na_indices = na_rows.index.values
len(na_indices)
# Out:
# 104

# %%
train.drop(na_indices)
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 0        A-2017855  MapQuest  201.0         2  2018-07-19 20:30:23
# 1        A-3340193      Bing    NaN         2  2020-12-27 13:22:48
# 2        A-3274372      Bing    NaN         2  2020-12-19 20:27:52
# 3        A-2782559      Bing    NaN         3  2016-09-27 17:29:27
# 4        A-3722269      Bing    NaN         2  2020-02-11 19:22:00
# ...            ...       ...    ...       ...                  ...
# 2962774  A-2142754  MapQuest  201.0         3  2018-05-22 14:32:36
# 2962775  A-1042473  MapQuest  201.0         2  2019-10-07 08:26:01
# 2962776  A-3843476      Bing    NaN         2  2019-11-13 07:57:00
# 2962777  A-3843901      Bing    NaN         2  2019-11-13 08:58:22
# 2962778  A-1621798  MapQuest  201.0         3  2019-01-04 08:24:15
#
#                     End_Time  Start_Lat   Start_Lng    End_Lat     End_Lng  \
# 0        2018-07-19 21:14:11  34.153896 -118.275482        NaN         NaN
# ...

# %%
df_subset = train.loc[:, 'Zipcode'].to_frame()
na_rows_zip = df_subset[~df_subset.notnull().all(axis=1)]
na_rows_zip
# Out:
#         Zipcode
# 3840        NaN
# 15818       NaN
# 17761       NaN
# 18597       NaN
# 19855       NaN
# ...         ...
# 2952823     NaN
# 2954900     NaN
# 2956061     NaN
# 2956409     NaN
# 2956483     NaN
#
# [933 rows x 1 columns]

# %%
na_rows_zip.index
# Out:
# Int64Index([   3840,   15818,   17761,   18597,   19855,   30030,   32594,
#               34473,   34564,   36594,
#             ...
#             2938819, 2938890, 2940959, 2942282, 2951395, 2952823, 2954900,
#             2956061, 2956409, 2956483],
#            dtype='int64', length=933)
